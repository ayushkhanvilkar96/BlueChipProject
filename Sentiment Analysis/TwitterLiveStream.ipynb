# %%
import time
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json
from textblob import TextBlob
import matplotlib.pyplot as plt
import re
from textblob import TextBlob

consumer_key='9cCgbabP4AZGxYgJrZ5qIIXdL'
consumer_secret='cHfFXmzqg5U5U0W7Uf8UmGSDL19OVofku4fOifDvezvdWBFs7a'
access_token='905969089-xpoyx12kekf5Nx8XULw4xBL2cB3kbBY9Ro14EDjJ'
access_token_secret='lfCsS81HQA9zUJwubs8JGZN3qkBAtkJ3sCzdrLNjO2dZT'

#Authentication Process
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
auth.secure = True
api = tweepy.API(auth)

class MyStreamListener(tweepy.StreamListener):

    def on_status(self, status):
        print(status.text)
        analysis=TextBlob(status.text)
        print(analysis.sentiment)
        
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth, listener=myStreamListener)

myStream.filter(track=['modi'], async=True)

#api.update_status('-__-')
# Out:
# @srinivav All classes, not just masses. Unlike modi, he doesn't use rhetoric but uses the right words in three languages.
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# RT @davidfrawleyved: Wise words of a great Yogi: A kind of deformity has come in Indian politics where anything can be done for appeasement…
# Sentiment(polarity=0.7000000000000001, subjectivity=0.85)
# RT @jigneshmevani80: अलिफ़ लैला और चालीस चोर :
# निरव मोदी ने डीमोनेटाइजेशन से पहले 90 करोड़ रुपये बैंक में जमा कराए थे तो इसका मतलब @narendr…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @thecaravanindia: A senior bureaucrat accuses KPMG of exercising influence over key government officials by, among other means, recruiti…
# Sentiment(polarity=-0.0625, subjectivity=0.6875)
# @firstpost Sridevi has saved the govt of modi RSS from the scam n media is happy
# Sentiment(polarity=0.8, subjectivity=1.0)
# @RavishKumar_ind Bikul chalenge. Sirf Modi ko vote denge!!!
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @iScrew: Yet another criminal wastage of water when Ahmedabad roads &amp; footpaths were washed for Modi’s pomp &amp; show when Netanyahu visite…
# Sentiment(polarity=-0.4, subjectivity=0.55)
# @ndtv @AmitShah @BJP4India Will you say something about Nirav Modi,how he &amp; your son developed?
# Sentiment(polarity=0.1, subjectivity=0.3)
# RT @withRG: #BJPLoanJihad Modi will speak his #MannKiBaat but he will never speak on frauds by his close aides.
# https://t.co/b8AvNs1thy
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @kapsology: Giving a FREE idea to opposition to counter 2022 jibe of Modi. Use your brains to counter this cunning fox. https://t.co/pDN…
# Sentiment(polarity=0.2, subjectivity=0.75)
# बड़ी जल्दी जाग गए 😂😂 https://t.co/oxqCwqPUx2
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @pbhushan1: Wow! https://t.co/SyvyMT5U6i
# Sentiment(polarity=0.125, subjectivity=1.0)
# Use AI to boost delivery of services: PM Modi
#  https://t.co/1hIbBJNHpB
#
# via NMApp https://t.co/iVesI5CRqp
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @thewire_in: Could the Punjab National Bank scam, involving celebrity diamantaire Nirav Modi, his uncle Mehul Choksi and others, have co…
# Sentiment(polarity=0.0, subjectivity=0.0)
# @RavishKumar_ind Soch liya aur samaj liya Jehadi...
# Vote karenge to Modi Ko warna kisi Ko nahi.  .
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @t_d_h_nair: 6/ 1.5 million jobs lost in just 3 months after demonetisation. Modi govt made life easier for people
# https://t.co/aaJLxu5G…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @sanjivbhatt: New company launched by Lalit Modi, Vijay Mallya and Nirav Modi : Hindustan Leaver 😜😜
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# RT @INCChhattisgarh: The suspension of Cong MLAs tells us that if PM Modi is silent, FM Arun Jaitley is silent then CM Raman Singh will not…
# Sentiment(polarity=0.0, subjectivity=0.1)
# RT @SandipGhose: Interesting that the only 2 non Gandhi-Nehru pictures in the room are Ambedkar and MMS (doubt for how long). No South Indi…
# Sentiment(polarity=0.15, subjectivity=0.6333333333333333)
# RT @theskindoctor13: Modi : Gaai hamari maata hai.
# Twitter feminist : https://t.co/bn7gW7pjML
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @AnisPFI: Now will BJP say Congress or Nehru is responsible? It is now clear that Chota Modi is a close BJP associate. And Choksi is alr…
# Sentiment(polarity=0.15000000000000002, subjectivity=0.4666666666666667)
# RT @i_me_my5elf: Narendra Modi used to question Manmohan Singh for being FM during Harshad Mehta Scam &amp; Prime Minister during Satyam comput…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @PrannoyRoyNDTV: “In India, Narendra Modi’s government has launched a highly questionable fraud and money laundering case against NDTV,…
# Sentiment(polarity=-0.5, subjectivity=1.0)
# RT @DrSaniaMaan: मित्रों,
#
# मैने 'उज्जवला' के तहत 300 करोड़ की गैस की सब्सिडी ली और उसमें से 297 करोड़ रामदेव को 'मेक इन इंडिया' के नाम पर…
# Sentiment(polarity=0.0, subjectivity=0.0)
# CONgress Government in Karnataka has created new records in Corruption, Farmers Suicides, Murder of Hindu Karyakart… https://t.co/mzKhV9OYDi
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# RT @ShefVaidya: Funny that Ambedkar is in this pic, after the way Nehru treated him all through! https://t.co/dXvcALdnyu
# Sentiment(polarity=0.3125, subjectivity=1.0)
# @narendramodi Why don't you tweet about any body death in India is there is no cost of common man in India....Pleas… https://t.co/bGUiLz6g0g
# Sentiment(polarity=-0.3, subjectivity=0.5)
# @bainjal now i think modi made sense when he raised a question on Nitish Kumar's DNA. You can question someone's DN… https://t.co/OGZpNgjY6m
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @SheelaSinghJi: हमें ऐसे प्रधानमंत्री मिले हैं जो हमें अक्सर अपने मन की बात सुनाते रहते हैं। काश प्रधानमंत्री आम जन के मन की बात भी सुन…
# Sentiment(polarity=0.0, subjectivity=0.0)
# PM Modi's Mann ki Baat: Waste-to-energy will enrich farmers, power villages
#  https://t.co/iLT4gwGa2E
#
# via NMApp https://t.co/ujqotzrAdW
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @INCIndia: Did #ChhotaModi and "Mehul Bhai" get an early heads-up allowing them to flee the country? So many questions and yet PM Modi r…
# Sentiment(polarity=0.3, subjectivity=0.4)
# @myogiadityanath Hatyari sarkar 450sm ki jaan Lekr pet nhi bhar rha
# Bnk looto kisaan maro garib janta ko bijli aur… https://t.co/8pwfJslY9c
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @ZeeNewsHindi: 48 महीने में हमने किया काम, 48 साल तक कांग्रेस ने किया कारोबार: पीएम मोदी
# https://t.co/PGK28vyfl3
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @i_theindian: Modi's biggest contribution since he became PM:
#
# 🔰India is the most corrupt country in Asia beating Vietnam, Thailand, Pak…
# Sentiment(polarity=0.0, subjectivity=0.75)
# @arvasudevan @mediacrooks Sab Modi ki Godi Main palne waale half witted abodh baalak hain
# Sentiment(polarity=0.0, subjectivity=0.25)
# RT @coolfunnytshirt: As per the past trends, one more golden opportunity for Rahul Gandhi to question Modi over crimes done by Congressis..…
# Sentiment(polarity=0.18333333333333335, subjectivity=0.4166666666666667)
# @ANI Mr @AmitShah let's have a debate between Modi and our CM on development not on pakoda please 😂😂 https://t.co/durFj5Y6b6
# Sentiment(polarity=0.0, subjectivity=0.0)
# kya kah rahe ho rahul ji 10 saal me aapne jo kiya vo modi kare no ye to ho nahi sakta modi ke raaj me aane vale 10… https://t.co/Yh5HpxXqyT
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @INCIndia: Did #ChhotaModi and "Mehul Bhai" get an early heads-up allowing them to flee the country? So many questions and yet PM Modi r…
# Sentiment(polarity=0.3, subjectivity=0.4)
# RT @t_d_h_nair: 7/ Mr Modi, is this the way you r going to make the life easier for people for one more year?
# https://t.co/FDq7Nh1mEW
# Sentiment(polarity=0.5, subjectivity=0.5)
# @Maha_Bharatham @RaviKum97122571 @IndiaFirstOK @sinhamilan @narendramodi Modi is a past. Think ahead. Enough of Pak… https://t.co/NXBwGbFN5p
# Sentiment(polarity=-0.125, subjectivity=0.375)
# RT @Ansarisajid99: @SunilKandalkar4 @sunil_807775572 @DhyaniSdhyani63 @DublishDeval @narendr21630865 @HajiAhmedPatel2 @KishanChandCss @alar…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @singh_biswajeet: Look at the date, Banks reported fraud to CBI on Nov'17, had Cong not attacked Modi on Mehul &amp; Nirav bhai Scams, Modi…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @BUSHINDIA: Yes CNBC 18,on Saturday highlighted this.Good MODI is closing up all loopholes .Offenders can not escape. https://t.co/qeARP…
# Sentiment(polarity=0.0, subjectivity=0.0)
# And main victim is Darbari’s and Pidi 😂😂😂 https://t.co/2SiTF8VwrI
# Sentiment(polarity=0.04583333333333332, subjectivity=0.19166666666666665)
# RT @advmajeedmemon: A report reveals that Nirav Modi deposited huge cash amount in one PNB branch on 8 th Nov. 2017, hours before PM announ…
# Sentiment(polarity=0.4000000000000001, subjectivity=0.9)
# PM Modi launches Amma scooter scheme, says it will empower women in TN
#  https://t.co/L6DpCsADiG
#
# via NMApp https://t.co/6wuCmCwWwL
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @INCKarnataka: In 2012, when Narendra Modi was CM, BJP promised to build 50 Lakh houses for the poor in Gujarat.
#
# As with all of BJP's…
# Sentiment(polarity=-0.4, subjectivity=0.6)
# RT @sanjivbhatt: New company launched by Lalit Modi, Vijay Mallya and Nirav Modi : Hindustan Leaver 😜😜
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# @gokula15sai Punjab C.M setuduvaara Modi?
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @JantaKaReporter: “Nirav Modi deposited Rs 90 crore hours before demonetisation announcement”
# https://t.co/hPY9IYwyTp
# Sentiment(polarity=0.0, subjectivity=0.0)
# @JoshiPralhad joshi, I believe you have woken up just now. What happened in Bangalore Modi Rally, Mysore rally and… https://t.co/AwEDZVeB4n
# Sentiment(polarity=0.0, subjectivity=0.0)
# Modi’s advisor estimates $46.5 billion of India’s bad loans will be “irretrievably lost” https://t.co/0G7ODIYBFD
# Sentiment(polarity=-0.6999999999999998, subjectivity=0.6666666666666666)
# RT @ThinkersPad: Nice thread. Pls read &amp; circulate. The fact is, @NarendraModi is plugging more and more legal holes.
#
# Fact is, offenders…
# Sentiment(polarity=0.45, subjectivity=0.55)
# RT @INCKarnataka: “Demonetisation was a scheme to convert black money of rich people to white. Poor &amp; middle class people stood in queues &amp;…
# Sentiment(polarity=-0.03833333333333334, subjectivity=0.35666666666666663)
# RT @singh_biswajeet: Modi selectively raided Capt Amrinder Singh son-in-law to counter Cong attack on PNB scam. these chaps knows each othe…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Let's build #NewIndia free of casteism and communalism to bring #IndiansOnTop in all walks of life, let it be sport… https://t.co/HqLgtb7Xmp
# Sentiment(polarity=0.4, subjectivity=0.8)
# A success story of success Politician Narendra Modi https://t.co/KA6EPashrl #forex #binaryoptions #cryptocurrency #stockmarket
# Sentiment(polarity=0.3, subjectivity=0.0)
# “Demonetisation was a scheme to convert black money of rich people to white. Poor &amp; middle class people stood in qu… https://t.co/XYixdqwb2h
# Sentiment(polarity=-0.03833333333333334, subjectivity=0.35666666666666663)
# RT @t_d_h_nair: 9/ To make the life of researchers easier, you did this too, Mr Modi
# https://t.co/ne1AgXK3mJ
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @guptar: Barf. Electoral politics necessarily tactical but vehemently disagree with ideology-free maneuvering represented by PK and his…
# Sentiment(polarity=0.0, subjectivity=1.0)
# What the fuck is the Modi government doing? This is not how a free market works! 😡
#
# https://t.co/2zUKii7ymA
# Sentiment(polarity=0.04999999999999999, subjectivity=0.7)
# RT @ShekharGupta: Analysts predicting Modi to be a one-term PM on seat-arithmetic are wrong. 2014 &amp; Gujarat show now polls are plebiscitary…
# Sentiment(polarity=-0.5, subjectivity=0.9)
# RT @DrHarish_Joshi: PM Modi launches Amma scooter scheme, says it will empower women in TN
# https://t.co/hAExdIW66U
#
# via NMApp https://t.co/…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @geetv79: Can Millions of Indians Deny
# That They Had Financial Transactions
# By Buying➡ Kingfisher/IPL Tickets❓
#
# Ridiculous
#
# https://t.…
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.5)
# RT @ibtimes_india: Sridevi dies: PM Modi, President Kovind mourn the untimely death of the English Vinglish actress
#
# #Sridevi #RIPSridevi @…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @geetv79: Mittronn.... "Hamare Desh Mein Anaap Shannap Bayanbaazi Karne Walon Ki Kami Nahin Hai, Har Din Naya Jhoot Bolne Mein Mahir Log…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @ShirishKunder: Can someone please help me with his astrologer's name? 🙏 https://t.co/seVQbh8J6w
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @ibtimes_india: Sridevi dies: PM Modi, President Kovind mourn the untimely death of the English Vinglish actress
#
# #Sridevi #RIPSridevi…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @t_d_h_nair: 10/ After u sworn in as PM, life of minorities and Dalits became much easier in India.
#
# https://t.co/6GdwXHRyGE
# Sentiment(polarity=0.2, subjectivity=0.2)
# New on Quartz: Modi’s advisor estimates $46.5 billion of India’s bad loans will be “irretrievably lost” https://t.co/xZlk84NJQi
# Sentiment(polarity=-0.28181818181818175, subjectivity=0.5606060606060606)
# “As compared to the large companies, SMEs hardly default. Before the Nirav Modi scam, hardly any businessmen in the… https://t.co/8tf8qqzOUW
# Sentiment(polarity=-0.12301587301587302, subjectivity=0.503968253968254)
# RT @imMAK02: In Yogi's UP, Varanasi
#
# 11th class student commits suicide in PM's constituency after she was beaten  up for resisting sexual…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @sanjivbhatt: New company launched by Lalit Modi, Vijay Mallya and Nirav Modi : Hindustan Leaver 😜😜
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# RT @jigneshmevani80: अलिफ़ लैला और चालीस चोर :
# निरव मोदी ने डीमोनेटाइजेशन से पहले 90 करोड़ रुपये बैंक में जमा कराए थे तो इसका मतलब @narendr…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @neo_pac: I've been convinced for months Modi will dismiss AAP govt. The consequences of @ArvindKejriwal winning again are unimaginable…
# Sentiment(polarity=0.5, subjectivity=0.75)
# RT @geetv79: Day to Day Safety Should be Part of our Lives
# Says Modi,
# As Party-Men, Drunk on Liquor &amp; Power
# Run Amok Killing Kids
#
# Kathn…
# Sentiment(polarity=-0.5, subjectivity=1.0)
# RT @advmajeedmemon: A report reveals that Nirav Modi deposited huge cash amount in one PNB branch on 8 th Nov. 2017, hours before PM announ…
# Sentiment(polarity=0.4000000000000001, subjectivity=0.9)
# 2019 में एक बार फिर बीजेपी की नैय्या पार लगाएंगे प्रशांत किशोर, थाम सकते हैं ‘टीम मोदी’ का दामन
# #PrashantKishor… https://t.co/lpxNJnPJX8
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @sadhavi: People don’t understand that PK was always a part of Team @narendramodi He never left him. He was sent on a mission to JDU &amp; C…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @ThinkersPad: Nice thread. Pls read &amp; circulate. The fact is, @NarendraModi is plugging more and more legal holes.
#
# Fact is, offenders…
# Sentiment(polarity=0.45, subjectivity=0.55)
# @mediacrooks @advmajeedmemon NCP Memon: A report says that Neerav Modi deposited huge cash just before Demo announc… https://t.co/olfsMOA4ek
# Sentiment(polarity=0.4000000000000001, subjectivity=0.9)
# RT @MLMANDOWARA: Narendra Modi’s Mann Ki Baat: New India possible only through women empowerment
#  https://t.co/eFpE76r0Tn
#
# via NMApp https:…
# Sentiment(polarity=0.04545454545454545, subjectivity=0.8181818181818182)
# RT @kaul_vivek: The Nirav Modi Fraud Tells Us That the Business of Government Should Not Be Business - Vivek Kaul's Diary https://t.co/vyof…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @INCKarnataka: In a meeting with Amit Shah, a farmer from Karnataka was manhandled when he asked questions about the anti-Farmer policie…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @barkhad: Interesting that jokes on Mr. Modi abound but leading comics afraid of cracking jokes on Mr. Shah.  https://t.co/kgSBkIj6z9
# Sentiment(polarity=-0.04999999999999999, subjectivity=0.7)
# RT @Ahmad_Shakeel: Nirav Modi ne PM Modi ki 8 Nov 2016 ko Notebandi ki ghoshna ke kuchh ghanta pahle hi 90 crore rupiye PNB mey kyon jama k…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @t_d_h_nair: 11/ But we know u did so many things to make the life of ur cronies tougher like gifting  tax bonanza
# https://t.co/xhDs1YTL…
# Sentiment(polarity=0.5, subjectivity=0.5)
# Is Modi a fool? https://t.co/F7fxQMc7EN
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @ShirishKunder: Can someone please help me with his astrologer's name? 🙏 https://t.co/seVQbh8J6w
# Sentiment(polarity=0.0, subjectivity=0.0)
# Modi launches flight, helicopter service between Ahmedabad and Daman &amp; Diu
#  https://t.co/yQIVrZ4eVT
#
# via NMApp https://t.co/iETA1z42AI
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @SaffronArrow: @Being_Humor
# Your conspiracy! https://t.co/I1FjgTlSkB
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @sanjayuvacha: Bullshitting has to have limits https://t.co/jGSE4Mneqb
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @sidmtweets: Justice Revati of Bombay HC who grilled CBI for delaying the Sohrabuddin Fake encounter case is transferred last week- only…
# Sentiment(polarity=-0.25, subjectivity=0.5333333333333333)
# RT @srivatsayb: This farmer should be careful during his morning walks.
#
# https://t.co/tomXcNSBqJ
# Sentiment(polarity=-0.1, subjectivity=1.0)
# RT @sanjivbhatt: New company launched by Lalit Modi, Vijay Mallya and Nirav Modi : Hindustan Leaver 😜😜
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Modi’s advisor estimates $46.5 billion of India’s bad loans will be “irretrievably lost” #Godrej #Jaitley #Arvind… https://t.co/SR4DCAXdSh
# Sentiment(polarity=-0.6999999999999998, subjectivity=0.6666666666666666)
# RT @CTRavi_BJP: CONgress Government in Karnataka has created new records in Corruption, Farmers Suicides, Murder of Hindu Karyakartas &amp; ter…
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# RT @DrGPradhan: The @incindia joker @officeofrg does not understand the difference between banks making a provision and write off.
#
#  https:…
# Sentiment(polarity=0.0, subjectivity=0.0)
# @nsheshagiri1 @ndtv bhai bjp leader muslim hai.. kabhi bhi nagpur se farmaan  aa jayega ki isko defend karne ki jar… https://t.co/OubT12QpVK
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @bprerna: Poori sarkar hi Gobar pe chal rahi hai https://t.co/Ls3lvXoZdi
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @OfficeOfRG: Under Modi Ji's "Jan Dhan Loot Yojana", another scam!
#
# 390 Cr., involving a Delhi based jeweller. Same Modus operandi as N…
# Sentiment(polarity=0.0, subjectivity=0.125)
# RT @manny_ottawa: “Trudeau, who arrived back in Ottawa Sunday morning, spent much of his time in India dodging and scrambling to address al…
# Sentiment(polarity=0.03333333333333333, subjectivity=0.10000000000000002)
# Between 2011 &amp; 2012, India’s goods exports totalled $249 billion.
#
# Five years later, in 2016-17, the figure was at… https://t.co/ccvKZfaOOZ
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @t_d_h_nair: 12/ And to make the life easier for Indians, you helped fraudsters slip out of the country so easily. Isn’t it Mr Modi?
# htt…
# Sentiment(polarity=0.43333333333333335, subjectivity=0.8333333333333334)
# RT @bsindia: #PNBScam
# Nirav Modi deposited Rs 900 million in PNB hours before #demonetisation, says NCP's Majeed Memon https://t.co/FSUoDK8…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @Being_Humor: PK left congress for payment even though he was getting paid by BJP only to make it look real. PK still working &amp; more com…
# Sentiment(polarity=0.175, subjectivity=0.45)
